# %%
import pandas as pd

# File paths
file_path1 = 'EPR-Org_PUBLIC.xlsx'
file_path2 = 'Master data EPR.xlsx'

# Load the first few rows of each file to inspect
data1 = pd.read_excel(file_path1)
data2 = pd.read_excel(file_path2)

# %%
columns1 = data1.columns.tolist()
columns1
# Out:
# ['country',
#  'gwid',
#  'orgid',
#  'orgname',
#  'linkid',
#  'EPR group',
#  'EPR groupid',
#  'year',
#  'Ethnic claim',
#  'Ethnic electoral support',
#  'Ethnic recruitment',
#  'Founding year',
#  'Dissolution year',
#  'Governmental power',
#  'Regional autonomy',
#  'Separatism/irredentism',
#  'Economic redistribution',
#  'Religious rights',
#  'Linguistic rights',
#  'Other goals',
#  'Electoral participation',
#  'Nonelectoral, nonviolent strategies',
#  'Violence against government',
#  'Violence against civilians',
#  'Other mobilization strategies',
#  'Sources',
#  'Comments',
#  'Confidence']

# %%
columns2 = data2.columns.tolist()
columns2
# Out:
# ['gwgroupid',
#  'countries_gwid',
#  'year',
#  'groupname',
#  'countryname',
#  'isactive',
#  'isrelevant',
#  'groupsize',
#  'statusid',
#  'statusname',
#  'regaut',
#  'status_pwrrank',
#  'status_monopoly',
#  'status_dominant',
#  'status_senior',
#  'status_junior',
#  'status_selfexclusion',
#  'status_powerless',
#  'status_discrim',
#  'status_egip',
#  'status_excl',
#  'egip_groups_count',
#  'excl_groups_count',
#  'rlvt_groups_count',
#  'actv_groups_count',
#  'lpop',
#  'lsize',
#  'egippop',
#  'legippop',
#  'exclpop',
#  'lexclpop',
#  'discrimpop',
#  'ldiscrimpop',
#  'rbal',
#  'rlbal',
#  'downgraded1',
#  'downgraded_excl1',
#  'downgraded_regaut1',
#  'upgraded1',
#  'upgraded_excl1',
#  'upgraded_regaut1',
#  'downgraded2',
#  'downgraded_excl2',
#  'downgraded_regaut2',
#  'upgraded2',
#  'upgraded_excl2',
#  'upgraded_regaut2',
#  'downgraded5',
#  'downgraded_excl5',
#  'downgraded_regaut5',
#  'upgraded5',
#  'upgraded_excl5',
#  'upgraded_regaut5',
# ...

# %%
data1["gwid"].unique()
# Out:
# array([ 52,  92, 135, 140, 150, 211, 230, 340, 343, 346, 365, 368, 373,
#        404, 510, 516, 540, 541, 552, 553, 565, 571, 580, 615, 626, 640,
#        645, 666, 678, 710, 713, 770, 771, 775, 780, 820, 900])

# %%
data1["year"].unique()
# Out:
# array([1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972,
#        1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#        1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 1946, 1947, 1948,
#        1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960, 1961])

# %%
 data1["country"].unique()
# Out:
# array(['Trinidad and Tobago', 'El Salvador', 'Peru', 'Brazil', 'Paraguay',
#        'Belgium', 'Spain', 'Serbia', 'Macedonia',
#        'Bosnia and Herzegovina', 'Russia', 'Lithuania', 'Azerbaijan',
#        'Guinea-Bissau', 'Tanzania', 'Burundi', 'Angola', 'Mozambique',
#        'Zimbabwe', 'Malawi', 'Namibia', 'Botswana', 'Madagascar',
#        'Algeria', 'South Sudan', 'Turkey', 'Iraq', 'Israel', 'Yemen',
#        'China', 'Taiwan', 'Pakistan', 'Bangladesh', 'Myanmar',
#        'Sri Lanka', 'Malaysia', 'Australia'], dtype=object)

# %%
data2["year"].unique()
# Out:
# array([1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
 data2["countryname"].unique()
# Out:
# array(['United States of America', 'Canada', 'Bahamas', 'Cuba', 'Haiti',
#        'Dominican Republic', 'Jamaica', 'Trinidad and Tobago', 'Barbados',
#        'Mexico', 'Belize', 'Guatemala', 'Honduras', 'El Salvador',
#        'Nicaragua', 'Costa Rica', 'Panama', 'Colombia', 'Venezuela',
#        'Guyana', 'Surinam', 'Ecuador', 'Peru', 'Brazil', 'Bolivia',
#        'Paraguay', 'Chile', 'Argentina', 'Uruguay', 'United Kingdom',
#        'Ireland', 'Netherlands', 'Belgium', 'Luxembourg', 'France',
#        'Switzerland', 'Spain', 'Portugal', 'German Federal Republic',
#        'German Democratic Republic', 'Poland', 'Austria', 'Hungary',
#        'Czechoslovakia', 'Czech Republic', 'Slovakia', 'Italy/Sardinia',
#        'Malta', 'Albania', 'Serbia', 'Montenegro',
#        'Macedonia (FYROM/North Macedonia)', 'Croatia', 'Yugoslavia',
#        'Bosnia-Herzegovina', 'Kosovo', 'Slovenia', 'Greece', 'Cyprus',
#        'Bulgaria', 'Moldova', 'Rumania', 'Russia (Soviet Union)',
# ...

# %%
 data2["countries_gwid"].unique()
# Out:
# array([  2,  20,  31,  40,  41,  42,  51,  52,  53,  70,  80,  90,  91,
#         92,  93,  94,  95, 100, 101, 110, 115, 130, 135, 140, 145, 150,
#        155, 160, 165, 200, 205, 210, 211, 212, 220, 225, 230, 235, 260,
#        265, 290, 305, 310, 315, 316, 317, 325, 338, 339, 340, 341, 343,
#        344, 345, 346, 347, 349, 350, 352, 355, 359, 360, 365, 366, 367,
#        368, 369, 370, 371, 372, 373, 375, 380, 385, 390, 395, 402, 404,
#        411, 420, 432, 433, 434, 435, 436, 437, 438, 439, 450, 451, 452,
#        461, 471, 475, 481, 482, 483, 484, 490, 500, 501, 510, 511, 516,
#        517, 520, 522, 530, 531, 540, 541, 551, 552, 553, 560, 565, 570,
#        571, 572, 580, 581, 590, 600, 615, 616, 620, 625, 626, 630, 640,
#        645, 651, 652, 660, 663, 666, 670, 678, 680, 690, 692, 694, 696,
#        698, 700, 701, 702, 703, 704, 705, 710, 711, 712, 713, 731, 732,
#        740, 750, 760, 770, 771, 775, 780, 781, 790, 800, 811, 812, 816,
# ...

# %%
data1
# Out:
#                    country  gwid  orgid  \
# 0      Trinidad and Tobago    52      1
# 1      Trinidad and Tobago    52      1
# 2      Trinidad and Tobago    52      1
# 3      Trinidad and Tobago    52      1
# 4      Trinidad and Tobago    52      1
# ...                    ...   ...    ...
# 16655               Israel   666    714
# 16656               Israel   666    714
# 16657               Israel   666    714
# 16658               Israel   666    714
# 16659               Israel   666    714
#
#                                                  orgname  linkid  \
# 0                        African National Congress (ANC)       1
# 1                        African National Congress (ANC)       1
# 2                        African National Congress (ANC)       1
# 3                        African National Congress (ANC)       1
# 4                        African National Congress (ANC)       1
# ...                                                  ...     ...
# ...

# %%
data2
# Out:
#        gwgroupid  countries_gwid  year groupname               countryname  \
# 0         201000               2  1946    Whites  United States of America
# 1         201000               2  1947    Whites  United States of America
# 2         201000               2  1948    Whites  United States of America
# 3         201000               2  1949    Whites  United States of America
# 4         201000               2  1950    Whites  United States of America
# ...          ...             ...   ...       ...                       ...
# 54491   95002000             950  2016   Indians                      Fiji
# 54492   95002000             950  2017   Indians                      Fiji
# 54493   95002000             950  2018   Indians                      Fiji
# 54494   95002000             950  2019   Indians                      Fiji
# 54495   95002000             950  2020   Indians                      Fiji
#
# ...

# %%
import pandas as pd


data2.rename(columns={'countryname': 'country', 'countries_gwid': 'gwid'}, inplace=True)


merged_data = pd.merge(data1, data2, on=['year', 'country', 'gwid'], how='inner')

merged_data.to_excel('merged_output.xlsx', index=False)

# %%
merged_data
# Out:
#                    country  gwid  orgid                           orgname  \
# 0      Trinidad and Tobago    52      1   African National Congress (ANC)
# 1      Trinidad and Tobago    52      1   African National Congress (ANC)
# 2      Trinidad and Tobago    52      3     Democratic Labour Party (DLP)
# 3      Trinidad and Tobago    52      3     Democratic Labour Party (DLP)
# 4      Trinidad and Tobago    52      4  People's National Movement (PNM)
# ...                    ...   ...    ...                               ...
# 66725            Australia   900    711       Australian League of Rights
# 66726            Australia   900    711       Australian League of Rights
# 66727            Australia   900    711       Australian League of Rights
# 66728            Australia   900    711       Australian League of Rights
# 66729            Australia   900    711       Australian League of Rights
#
#        linkid     EPR group  EPR groupid  year  Ethnic claim  \
# ...

# %%
from IPython.display import FileLink
FileLink('merged_output.xlsx')
# Out:
# /Users/Patron/Desktop/untitled folder/Untitled Folder/merged_output.xlsx
